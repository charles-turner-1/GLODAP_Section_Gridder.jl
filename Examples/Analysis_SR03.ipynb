# %%
import Pkg
Pkg.activate("..")
Pkg.instantiate()
# Out:
#   Activating project at `~/Julia/GLODAP_Section_Gridder.jl`
# Precompiling project...
#    3556.7 ms  ? GLODAP_Section_Gridder

# %%
include("../src/GLODAP_Section_Gridder.jl")
using .GLODAP_Section_Gridder: grid_cruise

# %%
using Debugger
@trace DIVAnd

# %%
grid_cruise(
    "09AR19910925",
    "SR03",
    "G2theta",
    "isobaric"
)
